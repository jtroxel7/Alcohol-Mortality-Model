# %% [raw]
# ---
# title: "Project Code"
# subtitle: LCJJ
# author: Lainey Neild, Charlie Lovett, Jacob Muriel, Jack Troxel
# date: 02/27/2023
# number-sections: true
# abstract: _This file contains the code for the project on Alcohol Consumption, as part of the STAT303-2 course in Winter 2023.
# format:
#   html:
#     toc: true
#     toc-title: Contents
#     self-contained: true
#     font-size: 100%
#     toc-depth: 4
#     mainfont: serif
# jupyter: python3
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as sm
import time
import itertools
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data quality check / cleaning / preparation

# %% [markdown]
# ### Data cleaning
# *By Charlie Lovett*
#
# We created our dataset by accumulating data for singular predictors by country from the WHO website. For each of these individual datasets, we removed unnecessary columns and then merged them all together by country. We then exported this merged dataset as 'merged.csv' to use to create our model. For the sake of simplicity, we have not included the code that we used to clean all of our predictors, but the following code offers an example of the cleaning that was done on one dataset (beer as a share of alcohol consumption for each country).

# %%
beershare = pd.read_csv("Datasets/beer-as-share-alcohol-consumption.csv")
beershare.head()
# Out:
#                 Entity Code  Year  \
# 0              Albania  ALB  2016
# 1              Algeria  DZA  2016
# 2              Andorra  AND  2016
# 3               Angola  AGO  2016
# 4  Antigua and Barbuda  ATG  2016
#
#    Indicator:Alcohol, consumption of pure alcohol by type of beverage (%) - Beverage Types:Beer
# 0                                               34.3
# 1                                               57.3
# 2                                               34.1
# 3                                               70.3
# 4                                               33.0

# %%
beershare = beershare.rename(columns = {"Indicator:Alcohol, consumption of pure alcohol by type of beverage (%) - Beverage Types:Beer": "beer_as_share_alcohol_consumption", "Entity": "Country"})
beershare = beershare.drop(columns = {"Code","Year"})
beershare.head()
# Out:
#                Country  beer_as_share_alcohol_consumption
# 0              Albania                               34.3
# 1              Algeria                               57.3
# 2              Andorra                               34.1
# 3               Angola                               70.3
# 4  Antigua and Barbuda                               33.0

# %% [markdown]
# We had a significant number of predictors that contained at least a few missing values. We imputed each of these missing values by using the average value of the predictor.

# %%
train = train.fillna(train.mean())

# %% [markdown]
# ### Data quality check
# *By Lainey Neild*

# %%
# Reading and quickly removing unnecessary columns from the merged dataset
train = pd.read_csv('Datasets/merged.csv')
train = train.drop(columns = {'Unnamed: 0.2','Unnamed: 0.1','Unnamed: 0','Country', 'alc_attributed_fraction_deaths','Region'}, index = 182)
train = train.rename(columns = {'too_many_alc_deaths': 'high_risk'})
train.head()
# Out:
#    wine_as_share_alcohol_consumption  beer_as_share_alcohol_consumption  \
# 0                               26.5                               34.3
# 1                               24.4                               57.3
# 2                               17.6                               70.3
# 3                               18.3                               33.0
# 4                               40.2                               39.9
#
#    spirits_as_share_alcohol_consumption  \
# 0                                  37.6
# 1                                  18.3
# 2                                  11.3
# 3                                  45.4
# 4                                   9.6
#
#    tot_alcohol_consumption_per_capita_liters  gdp_per_capita  Population  \
# 0                                       6.74    11878.454102   2882482.0
# 1                                       0.93    11696.950195  39543148.0
# 2                                       7.96     8036.411133  28127724.0
# 3                                       5.89    18594.544922     89958.0
# 4                                       9.55    23933.886719  43257064.0
#
#    percent_who_have_not_drank_alcohol_in_last_year  perc_life_no_drink  \
# 0                                             49.0                25.2
# 1                                             96.8                93.5
# 2                                             52.3                33.9
# 3                                             50.6                27.7
# 4                                             32.6                 6.7
#
#    total_alcohol_consumption_per_capita_liters  \
# 0                                         6.74
# 1                                         0.93
# 2                                         7.96
# 3                                         5.89
# 4                                         9.55
#
#    percent_who_have_drank_alcohol_in_last_year  ...  \
# 0                                         51.0  ...
# 1                                          3.2  ...
# 2                                         47.7  ...
# 3                                         49.4  ...
# 4                                         67.4  ...
#
#    perc_heavy_drinkers_both_sexes  perc_heavy_drinkers_female  \
# 0                            44.7                        23.7
# 1                            19.3                         6.2
# 2                            81.6                        66.8
# 3                            47.2                        25.9
# 4                            32.5                        15.2
#
#    perc_heavy_drinkers_male  perc_consume_alc_past12  \
# 0                      57.4                     51.0
# 1                      23.5                      3.2
# 2                      90.1                     47.7
# 3                      60.9                     49.4
# 4                      45.5                     67.4
#
#    perc_consume_alc_past12Female  perc_consume_alc_past12Male  perc_dependent  \
# 0                           37.6                         65.0             3.4
# 1                            1.5                          4.8             0.7
# 2                           34.3                         61.6             2.1
# 3                           36.5                         63.9             2.7
# 4                           55.7                         79.9             2.9
#
#    perc_dependent_female  perc_dependent_male  high_risk
# 0                    1.4                  5.5          1
# 1                    0.0                  1.4          0
# 2                    0.7                  3.6          1
# 3                    1.8                  3.8          0
# 4                    1.2                  4.8          0
#
# [5 rows x 40 columns]

# %% [markdown]
# The code below visualizes the distribution of all the variables in the dataset, and their association with the response.

# %%
# Distribution of all 41 continuous variables in the dataset
train.describe()
# Out:
#        wine_as_share_alcohol_consumption  beer_as_share_alcohol_consumption  \
# count                         172.000000                         172.000000
# mean                           15.976163                          44.012791
# std                            17.464502                          22.156349
# min                             0.000000                           2.300000
# 25%                             2.100000                          29.275000
# 50%                             8.400000                          40.400000
# 75%                            27.925000                          57.450000
# max                            80.200000                         100.000000
#
#        spirits_as_share_alcohol_consumption  \
# count                            172.000000
# mean                              28.788953
# std                               23.657400
# min                                0.000000
# 25%                               10.500000
# 50%                               23.850000
# 75%                               42.150000
# max                               97.300000
#
#        tot_alcohol_consumption_per_capita_liters  gdp_per_capita  \
# count                                 176.000000      176.000000
# mean                                    6.147551    19310.667153
# std                                     4.199294    20029.814706
# min                                     0.003000      825.205688
# 25%                                     2.190000     4382.449463
# 50%                                     5.910000    11934.864258
# 75%                                     9.580000    27912.890625
# max                                    18.350000   113182.726562
#
#          Population  percent_who_have_not_drank_alcohol_in_last_year  \
# count  1.760000e+02                                       175.000000
# mean   4.119821e+07                                        60.602857
# std    1.491975e+08                                        23.334798
# min    8.995800e+04                                         8.200000
# 25%    2.299560e+06                                        40.800000
# 50%    8.799540e+06                                        63.600000
# 75%    2.933118e+07                                        78.100000
# max    1.393715e+09                                        99.900000
#
#        perc_life_no_drink  total_alcohol_consumption_per_capita_liters  \
# count          181.000000                                   182.000000
# mean            44.183978                                     6.044143
# std             28.284171                                     4.194188
# min              3.400000                                     0.003000
# 25%             17.900000                                     2.152500
# 50%             41.600000                                     5.825000
# 75%             66.400000                                     9.550000
# max             99.500000                                    18.350000
#
#        percent_who_have_drank_alcohol_in_last_year  ...  \
# count                                   174.000000  ...
# mean                                     39.445402  ...
# std                                      23.393383  ...
# min                                       0.100000  ...
# 25%                                      21.900000  ...
# 50%                                      36.400000  ...
# 75%                                      59.450000  ...
# max                                      91.800000  ...
#
#        perc_heavy_drinkers_both_sexes  perc_heavy_drinkers_female  \
# count                      161.000000                  161.000000
# mean                        41.386957                   21.839752
# std                         15.211181                   12.454734
# min                          1.900000                    0.500000
# 25%                         35.000000                   15.500000
# 50%                         42.500000                   20.800000
# 75%                         48.700000                   25.800000
# max                         88.100000                   79.100000
#
#        perc_heavy_drinkers_male  perc_consume_alc_past12  \
# count                161.000000               160.000000
# mean                  51.893789                39.180625
# std                   17.808950                23.674946
# min                    2.300000                 0.100000
# 25%                   45.500000                21.825000
# 50%                   54.300000                35.050000
# 75%                   60.900000                59.775000
# max                   94.300000                91.800000
#
#        perc_consume_alc_past12Female  perc_consume_alc_past12Male  \
# count                     160.000000                   160.000000
# mean                       29.308750                    49.277500
# std                        21.790539                    26.230174
# min                         0.100000                     0.200000
# 25%                        12.750000                    31.000000
# 50%                        22.950000                    48.150000
# 75%                        46.850000                    72.825000
# max                        87.700000                    95.800000
#
#        perc_dependent  perc_dependent_female  perc_dependent_male   high_risk
# count      161.000000             161.000000           161.000000  183.000000
# mean         2.301863               0.903106             3.780124    0.284153
# std          1.744042               0.800033             2.993510    0.452247
# min          0.100000               0.000000             0.200000    0.000000
# 25%          0.700000               0.200000             1.400000    0.000000
# 50%          2.500000               0.700000             3.900000    0.000000
# 75%          3.000000               1.400000             5.100000    1.000000
# max         11.000000               3.800000            19.600000    1.000000
#
# [8 rows x 40 columns]

# %%
# Distribution of regions in the dataset
train.Region.value_counts()
# Out:
# Europe                   45
# Africa                   43
# Americas                 30
# Eastern Mediterranean    19
# Western Pacific          16
# South-East Asia           9
# Name: Region, dtype: int64

# %%
# Visualize the distribution of observations that do / don't classify as high risk for alcohol related mortality
sns.countplot(data=train, x='high_risk')
# Out:
# <AxesSubplot:xlabel='high_risk', ylabel='count'>

# %% [markdown]
# ### Data preparation
# *By Jack Troxel*
#
# The following data preparation steps helped us to prepare our data for implementing various modeling / validation techniques:
#
# 1. We first created our response variable artificially. We did this by classifying observations with alcohol attributable mortality rates greater than 6% as high risk. This value was determined based on information from the WHO website.
#
# 2. We shuffled our dataset to prepare for K-fold cross validation. Since we have population data in this case, K-fold CV will help us to analyze whether the model that we generate is better than a naive model that uses all of the predictors.

# %%
# Creating our response variable
train['high_risk'] = train['alc_attributed_fraction_deaths'].apply(lambda x: 1 if x>6 else 0)

# %%
# Shuffling the dataset for K-fold CV
train = train.sample(frac=1)
train.head()
# Out:
#      wine_as_share_alcohol_consumption  beer_as_share_alcohol_consumption  \
# 107                          10.400000                          60.200000
# 178                          15.976163                          44.012791
# 119                           2.700000                          95.200000
# 87                           15.400000                          33.900000
# 140                           2.900000                          93.300000
#
#      spirits_as_share_alcohol_consumption  \
# 107                             13.900000
# 178                             28.788953
# 119                              2.100000
# 87                              49.200000
# 140                              3.300000
#
#      tot_alcohol_consumption_per_capita_liters  gdp_per_capita   Population  \
# 107                                       5.23    10662.830078    2282709.0
# 178                                       0.29     4278.346680  210969296.0
# 119                                       1.39     4083.752441    8682172.0
# 87                                        1.65    16358.375977    6398941.0
# 140                                       1.55     2518.647461     612670.0
#
#      percent_who_have_not_drank_alcohol_in_last_year  perc_life_no_drink  \
# 107                                        69.700000                54.3
# 178                                        98.800000                96.5
# 119                                        86.300000                67.6
# 87                                         93.900000                90.1
# 140                                        60.602857                97.1
#
#      total_alcohol_consumption_per_capita_liters  \
# 107                                         5.23
# 178                                         0.29
# 119                                         1.39
# 87                                          1.65
# 140                                         1.55
#
#      percent_who_have_drank_alcohol_in_last_year  ...  \
# 107                                    30.300000  ...
# 178                                     1.200000  ...
# 119                                    13.700000  ...
# 87                                      6.100000  ...
# 140                                    39.445402  ...
#
#      perc_heavy_drinkers_both_sexes  perc_heavy_drinkers_female  \
# 107                            59.7                        35.5
# 178                             5.3                         1.5
# 119                            60.7                        34.0
# 87                             20.2                         6.8
# 140                            60.3                        34.4
#
#      perc_heavy_drinkers_male  perc_consume_alc_past12  \
# 107                      71.6                     30.3
# 178                       6.5                      1.2
# 119                      70.2                     13.7
# 87                       24.5                      6.1
# 140                      69.9                      0.7
#
#      perc_consume_alc_past12Female  perc_consume_alc_past12Male  \
# 107                           19.1                         42.4
# 178                            0.6                          1.8
# 119                            7.3                         19.9
# 87                             3.0                          9.2
# 140                            0.3                          1.1
#
#      perc_dependent  perc_dependent_female  perc_dependent_male  high_risk
# 107             2.2                    0.8                  3.7          1
# 178             0.2                    0.1                  0.3          0
# 119             2.9                    0.7                  5.1          0
# 87              3.7                    0.0                  7.4          0
# 140             2.9                    0.7                  5.1          0
#
# [5 rows x 40 columns]

# %% [markdown]
# ## Exploratory data analysis
# *By Charlie Lovett and Jack Troxel*

# %%
# Examine which predictors are most strongly correlated with the response variable
train.corrwith(train.high_risk).sort_values(ascending = False)
# Out:
# high_risk                                          1.000000
# tot_alcohol_consumption_per_capita_liters          0.447922
# daly_alc_use_disorders__all_ages_standardized      0.402697
# daly_alc_use_disorders_15_49                       0.399031
# perc_heavy_drinkers_male                           0.398390
# perc_heavy_drinkers_both_sexes                     0.392347
# share_alc_use_disorders_both_sexes                 0.382273
# prev_alc_use_disorders_age_70                      0.377033
# perc_dependent_male                                0.358100
# prev_alc_use_disorders_all_ages                    0.341563
# perc_dependent                                     0.336831
# prev_alc_use_disorders_age_30_34                   0.315213
# prev_alc_use_disorders_age_standardized            0.308772
# daly_alc_use_disorders_70                          0.298798
# prev_alc_use_disorders_age_15_49                   0.288511
# perc_consume_alc_past12Male                        0.252372
# prev_alc_use_disorders_age_25_29                   0.248017
# percent_who_have_drank_alcohol_in_last_year        0.240359
# perc_consume_alc_past12                            0.227619
# share_alc_use_disorders_female                     0.224914
# perc_dependent_female                              0.216054
# perc_consume_alc_past12Female                      0.194790
# prev_alc_use_disorders_age_20_24                   0.125857
# spirits_as_share_alcohol_consumption               0.089503
# prev_alc_use_disorders_age_15_19                   0.072477
# prev_alc_use_disorders_age_10_14                   0.036492
# daly_alc_use_disorders_5_14                        0.024377
# prev_alc_use_disorders_age_5_14                    0.005128
# beer_as_share_alcohol_consumption                 -0.008461
# Population                                        -0.065937
# wine_as_share_alcohol_consumption                 -0.071796
# gdp_per_capita                                    -0.077118
# percent_who_have_not_drank_alcohol_in_last_year   -0.235161
# perc_life_no_drink                                -0.329732
# dtype: float64

# %%
# For the 6 most correlated predictors, examine the relationship between a binned version of each
# of these variables and the response variable to determine any possible transformations

fig, axes = plt.subplots(2,3,figsize=(22,12),sharey=True)
fig.text(0.07, 0.5, 'Percent High Risk', va='center', rotation='vertical')

#1
binned1 = pd.qcut(train['total_alcohol_consumption_per_capita_liters'],15,retbins=True)
train['total_alcohol_consumption_per_capita_liters'] = binned1[0]
new_data = train.groupby('total_alcohol_consumption_per_capita_liters')['high_risk'].agg([('hi_percent','mean'),('nobs','count')]).reset_index(drop=False)
ax = sns.lineplot(ax=axes[0,0], x=new_data.index, y= new_data['hi_percent'])
axes[0,0].set_xlabel('total_alcohol_consumption_per_capita_liters')
axes[0,0].set_ylabel('')


#2
binned2 = pd.qcut(train['share_alc_use_disorders_male'],15,retbins=True)
train['share_alc_use_disorders_male'] = binned2[0]
new_data = train.groupby('share_alc_use_disorders_male')['high_risk'].agg([('hi_percent','mean'),('nobs','count')]).reset_index(drop=False)
ax = sns.lineplot(ax=axes[0,1], x=new_data.index, y= new_data['hi_percent'])
axes[0,1].set_xlabel('share_alc_use_disorders_male')

#3
binned3 = pd.qcut(train['perc_heavy_drinkers_female'],15,retbins=True)
train['perc_heavy_drinkers_female'] = binned3[0]
new_data = train.groupby('perc_heavy_drinkers_female')['high_risk'].agg([('hi_percent','mean'),('nobs','count')]).reset_index(drop=False)
ax = sns.lineplot(ax=axes[0,2], x=new_data.index, y= new_data['hi_percent'])
axes[0,2].set_xlabel('perc_heavy_drinkers_female')

#4
binned4 = pd.qcut(train['daly_alc_use_disorders_50_69'],15,retbins=True)
train['daly_alc_use_disorders_50_69'] = binned4[0]
new_data = train.groupby('daly_alc_use_disorders_50_69')['high_risk'].agg([('hi_percent','mean'),('nobs','count')]).reset_index(drop=False)
ax = sns.lineplot(ax=axes[1,0], x=new_data.index, y= new_data['hi_percent'])
axes[1,0].set_xlabel('daly_alc_use_disorders_50_69')
axes[1,0].set_ylabel('')

#5
binned5 = pd.qcut(train['daly_alc_use_disorders_all_ages'],15,retbins=True)
train['daly_alc_use_disorders_all_ages'] = binned5[0]
new_data = train.groupby('daly_alc_use_disorders_all_ages')['high_risk'].agg([('hi_percent','mean'),('nobs','count')]).reset_index(drop=False)
ax = sns.lineplot(ax=axes[1,1], x=new_data.index, y= new_data['hi_percent'])
axes[1,1].set_xlabel('daly_alc_use_disorders_all_ages')

#6
binned6 = pd.qcut(train['prev_alc_use_disorders_age_50_69'],15,retbins=True)
train['prev_alc_use_disorders_age_50_69'] = binned6[0]
new_data = train.groupby('prev_alc_use_disorders_age_50_69')['high_risk'].agg([('hi_percent','mean'),('nobs','count')]).reset_index(drop=False)
ax = sns.lineplot(ax=axes[1,2], x=new_data.index, y= new_data['hi_percent'])
axes[1,2].set_xlabel('prev_alc_use_disorders_age_50_69')
# Out:
# Text(0.5, 0, 'prev_alc_use_disorders_age_50_69')

# %% [markdown]
# ## Developing the model
# *By Jacob Muriel*

# %% [markdown]
# #### Splitting up the train data into 7 equal-sized subsets
# *We chose to do this so that we can use K-Fold CV to test our models*

# %%
train0 = train.iloc[0:18,:]
train1 = train.iloc[18:36,:]
train2 = train.iloc[36:54,:]
train3 = train.iloc[54:72,:]
train4 = train.iloc[72:90,:]
train5 = train.iloc[90:108,:]
train6 = train.iloc[108:126,:]
train7 = train.iloc[126:144,:]
train8 = train.iloc[144:163,:]
train9 = train.iloc[163:182,:]

trains = [train0,train1,train2,train3,train4,train5,train6,train7,train8,train9]

# %%
#Function to compute confusion matrix and prediction accuracy on test data
def model_results(data,actual_values,model,cutoff=0.5):
    pred_values = model.predict(data)
    bins=np.array([0,cutoff,1])
    cm = np.histogram2d(actual_values, pred_values, bins=bins)[0]
    cm_df = pd.DataFrame(cm)
    cm_df.columns = ['Predicted 0','Predicted 1']
    cm_df = cm_df.rename(index={0: 'Actual 0',1:'Actual 1'})
    accuracy = (cm[0,0]+cm[1,1])/cm.sum()
    fnr = cm[1,0] / (cm[1,0] + cm[1,1])
    return [fnr,accuracy]

# %% [markdown]
# #### Naive Model (model using all predictors)

# %%
# Developing a model using all of the predictors in the data set
columns = train.columns.to_list()
columns.remove('high_risk')

# %%
model = sm.logit(formula = 'high_risk~'+ '+'.join([str(x) for x in columns]), data = train).fit()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.135756
#          Iterations: 35
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# #### Creation of the Final Model

# %%
columns = train.columns.to_list()
columns.remove('high_risk')
X = train[columns]

def test_accuracy(data,actual_values,model,cutoff=0.5):
#Predict the values using the Logit model
    pred_values = model.predict(data)
# Specify the bins
    bins=np.array([0,cutoff,1])
#Confusion matrix
    cm = np.histogram2d(actual_values, pred_values, bins=bins)[0]
    cm_df = pd.DataFrame(cm)
    cm_df.columns = ['Predicted 0','Predicted 1']
    cm_df = cm_df.rename(index={0: 'Actual 0',1:'Actual 1'})
# Calculate the accuracy
    accuracy = (cm[0,0]+cm[1,1])/cm.sum()
    return accuracy

#Function to develop a model based on all predictors in predictor_subset
def processSubset(predictor_subset):
    # Fit model on feature_set and calculate accuracy
    model = sm.logit('high_risk~' + '+'.join(predictor_subset),data = train).fit(method='bfgs')
    accuracy = test_accuracy(train,train.high_risk,model)
    return {"model":model, "accuracy":accuracy}

#Function to select the best model amongst all models with 'k' predictors
def getBest_model(k):
    tic = time.time()
    results = []
    for combo in itertools.combinations(X.columns, k):
        results.append(processSubset((list(combo))))

    # Wrap everything up in a dataframe
    models = pd.DataFrame(results)

    # Choose the model with the highest RSS
    best_model = models.loc[models['accuracy'].argmax()]
    
    toc = time.time()
    print("Processed", models.shape[0], "models on", k, "predictors in", (toc-tic), "seconds.")
    return best_model

def best_sub_plots():
    plt.figure(figsize=(20,10))
    plt.rcParams.update({'font.size': 18, 'lines.markersize': 10})

    # Set up a 2x2 grid so we can look at 3 plots at once
    plt.subplot(2, 2, 1)

    # We will now plot a red dot to indicate the model with the largest accuracy
    # The argmax() function can be used to identify the location of the maximum point of a vector
    plt.plot(models_best["accuracy"])
    plt.xlabel('# Predictors')
    plt.ylabel('accuracy')

    # We'll do the same for AIC and BIC, this time looking for the models with the SMALLEST statistic
    aic = models_best.apply(lambda row: row[1].aic, axis=1)

    plt.subplot(2, 2, 3)
    plt.plot(aic)
    plt.plot(1+aic.argmin(), aic.min(), "or")
    plt.xlabel('# Predictors')
    plt.ylabel('AIC')

    bic = models_best.apply(lambda row: row[1].bic, axis=1)

    plt.subplot(2, 2, 4)
    plt.plot(bic)
    plt.plot(1+bic.argmin(), bic.min(), "or")
    plt.xlabel('# Predictors')
    plt.ylabel('BIC')
    
#Function to find the best predictor out of p-k predictors and add it to the model containing the k predictors
def forward(predictors):

    # Pull out predictors we still need to process
    remaining_predictors = [p for p in X.columns if p not in predictors]
    
    tic = time.time()
    
    results = []
    
    for p in remaining_predictors:
        results.append(processSubset(predictors+[p]))
    
    # Wrap everything up in a nice dataframe
    models = pd.DataFrame(results)
    
    # Choose the model with the highest accuracy
    best_model = models.loc[models['accuracy'].argmax()]
    
    toc = time.time()
    print("Processed ", models.shape[0], "models on", len(predictors)+1, "predictors in", (toc-tic), "seconds.")
    
    # Return the best model, along with some other useful information about the model
    return best_model

def forward_selection():
    models_best = pd.DataFrame(columns=["accuracy", "model"])

    tic = time.time()
    predictors = []

    for i in range(1,len(X.columns)+1):    
        models_best.loc[i] = forward(predictors)
        predictors = list(models_best.loc[i]["model"].params.index[1:])

    toc = time.time()
    print("Total elapsed time:", (toc-tic), "seconds.")
    return models_best

# %%
models_best = forward_selection()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.595666
#          Iterations: 9
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 0.598235
#          Iterations: 12
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 0.594433
#          Iterations: 10
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 0.494554
#          Iterations: 9
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 0.595218
#          Iterations: 10
#          Function evaluations: 25
#          Gradient evaluations: 14
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.693147
#          Iterations: 0
#          Function evaluations: 15
#          Gradient evaluations: 3
# Optimization terminated successfully.
#          Current function value: 0.571713
#          Iterations: 11
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 0.539446
#          Iterations: 13
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 0.489519
#          Iterations: 7
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.570910
#          Iterations: 11
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 0.597612
#          Iterations: 19
#          Function evaluations: 20
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.595686
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 0.540367
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.568089
#          Iterations: 6
#          Function evaluations: 9
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.549508
#          Iterations: 7
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.590503
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.527500
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 0.557267
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.598256
#          Iterations: 18
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.516569
#          Iterations: 8
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.550824
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 0.518093
#          Iterations: 10
#          Function evaluations: 24
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 0.552642
#          Iterations: 8
#          Function evaluations: 17
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 0.597975
#          Iterations: 10
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 0.519708
#          Iterations: 13
#          Function evaluations: 25
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 0.518916
#          Iterations: 11
#          Function evaluations: 23
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 0.517856
#          Iterations: 10
#          Function evaluations: 25
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 0.533126
#          Iterations: 9
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 0.576915
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.519345
#          Iterations: 14
#          Function evaluations: 16
#          Gradient evaluations: 16
# Optimization terminated successfully.
#          Current function value: 0.520335
#          Iterations: 11
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 0.519218
#          Iterations: 9
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 0.509729
#          Iterations: 15
#          Function evaluations: 18
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.576199
#          Iterations: 11
#          Function evaluations: 14
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 0.582515
#          Iterations: 10
#          Function evaluations: 13
#          Gradient evaluations: 13
# Optimization terminated successfully.
#          Current function value: 0.570259
#          Iterations: 12
#          Function evaluations: 15
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 0.549387
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 12
# Optimization terminated successfully.
#          Current function value: 0.578850
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 11
# Optimization terminated successfully.
#          Current function value: 0.541641
#          Iterations: 8
#          Function evaluations: 11
#          Gradient evaluations: 11
# Processed  39 models on 1 predictors in 0.2373950481414795 seconds.
# Optimization terminated successfully.
#          Current function value: 0.514787
#          Iterations: 17
#          Function evaluations: 28
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.518307
#          Iterations: 17
#          Function evaluations: 27
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.518907
#          Iterations: 15
#          Function evaluations: 26
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.468501
#          Iterations: 13
#          Function evaluations: 25
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 0.506624
#          Iterations: 17
#          Function evaluations: 31
#          Gradient evaluations: 20
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.693147
#          Iterations: 0
#          Function evaluations: 15
#          Gradient evaluations: 3
# Optimization terminated successfully.
#          Current function value: 0.516656
#          Iterations: 19
#          Function evaluations: 26
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.504200
#          Iterations: 18
#          Function evaluations: 25
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.465218
#          Iterations: 13
#          Function evaluations: 25
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 0.516363
#          Iterations: 16
#          Function evaluations: 27
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.491287
#          Iterations: 26
#          Function evaluations: 38
#          Gradient evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.497577
#          Iterations: 18
#          Function evaluations: 30
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.518893
#          Iterations: 15
#          Function evaluations: 27
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.514607
#          Iterations: 16
#          Function evaluations: 28
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.518698
#          Iterations: 15
#          Function evaluations: 27
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.503427
#          Iterations: 17
#          Function evaluations: 29
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.515233
#          Iterations: 16
#          Function evaluations: 28
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.516394
#          Iterations: 16
#          Function evaluations: 28
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.489261
#          Iterations: 29
#          Function evaluations: 41
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.512194
#          Iterations: 15
#          Function evaluations: 27
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.517080
#          Iterations: 17
#          Function evaluations: 29
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.517513
#          Iterations: 16
#          Function evaluations: 28
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.518296
#          Iterations: 14
#          Function evaluations: 24
#          Gradient evaluations: 17
# Optimization terminated successfully.
#          Current function value: 0.488193
#          Iterations: 17
#          Function evaluations: 29
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.518623
#          Iterations: 14
#          Function evaluations: 27
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.516690
#          Iterations: 14
#          Function evaluations: 27
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.502289
#          Iterations: 16
#          Function evaluations: 27
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.518901
#          Iterations: 14
#          Function evaluations: 26
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.492269
#          Iterations: 16
#          Function evaluations: 27
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.450204
#          Iterations: 19
#          Function evaluations: 30
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.454538
#          Iterations: 17
#          Function evaluations: 28
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.451900
#          Iterations: 18
#          Function evaluations: 29
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.516483
#          Iterations: 16
#          Function evaluations: 27
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.518459
#          Iterations: 15
#          Function evaluations: 26
#          Gradient evaluations: 18
# Optimization terminated successfully.
#          Current function value: 0.513967
#          Iterations: 17
#          Function evaluations: 28
#          Gradient evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.509545
#          Iterations: 16
#          Function evaluations: 27
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.518768
#          Iterations: 15
#          Function evaluations: 27
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 0.503234
#          Iterations: 16
#          Function evaluations: 27
#          Gradient evaluations: 19
# Processed  38 models on 2 predictors in 0.28687381744384766 seconds.
# Optimization terminated successfully.
#          Current function value: 0.449560
#          Iterations: 19
#          Function evaluations: 32
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.448294
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.445020
#          Iterations: 22
#          Function evaluations: 35
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.422213
#          Iterations: 20
#          Function evaluations: 31
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.442094
#          Iterations: 22
#          Function evaluations: 36
#          Gradient evaluations: 25
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.693147
#          Iterations: 0
#          Function evaluations: 15
#          Gradient evaluations: 3
# Optimization terminated successfully.
#          Current function value: 0.450189
#          Iterations: 24
#          Function evaluations: 33
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.441889
#          Iterations: 23
#          Function evaluations: 32
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.420278
#          Iterations: 20
#          Function evaluations: 31
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.450168
#          Iterations: 20
#          Function evaluations: 33
#          Gradient evaluations: 26
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.433194
#          Iterations: 35
#          Function evaluations: 46
#          Gradient evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.438716
#          Iterations: 27
#          Function evaluations: 38
#          Gradient evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.450126
#          Iterations: 24
#          Function evaluations: 35
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.447711
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.449944
#          Iterations: 22
#          Function evaluations: 33
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.441836
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.447235
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.448716
#          Iterations: 24
#          Function evaluations: 35
#          Gradient evaluations: 27
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.431040
#          Iterations: 35
#          Function evaluations: 46
#          Gradient evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.449813
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.448116
#          Iterations: 26
#          Function evaluations: 37
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.445467
#          Iterations: 21
#          Function evaluations: 34
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.449874
#          Iterations: 20
#          Function evaluations: 30
#          Gradient evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.431472
#          Iterations: 24
#          Function evaluations: 35
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.447083
#          Iterations: 22
#          Function evaluations: 37
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.450186
#          Iterations: 18
#          Function evaluations: 31
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.447175
#          Iterations: 19
#          Function evaluations: 30
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.448769
#          Iterations: 22
#          Function evaluations: 33
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.443150
#          Iterations: 21
#          Function evaluations: 32
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.450203
#          Iterations: 22
#          Function evaluations: 33
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.450135
#          Iterations: 19
#          Function evaluations: 29
#          Gradient evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.450159
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.449965
#          Iterations: 21
#          Function evaluations: 33
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.449622
#          Iterations: 21
#          Function evaluations: 32
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.448157
#          Iterations: 21
#          Function evaluations: 32
#          Gradient evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.449600
#          Iterations: 24
#          Function evaluations: 35
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.445529
#          Iterations: 21
#          Function evaluations: 32
#          Gradient evaluations: 24
# Processed  37 models on 3 predictors in 0.3642308712005615 seconds.
# Optimization terminated successfully.
#          Current function value: 0.447192
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.444661
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.422207
#          Iterations: 21
#          Function evaluations: 34
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.440268
#          Iterations: 24
#          Function evaluations: 40
#          Gradient evaluations: 29
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.693147
#          Iterations: 0
#          Function evaluations: 15
#          Gradient evaluations: 3
# Optimization terminated successfully.
#          Current function value: 0.448294
#          Iterations: 26
#          Function evaluations: 35
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.440081
#          Iterations: 25
#          Function evaluations: 34
#          Gradient evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.420270
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.448290
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 28
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.430331
#          Iterations: 35
#          Function evaluations: 47
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.436661
#          Iterations: 29
#          Function evaluations: 41
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.448261
#          Iterations: 27
#          Function evaluations: 39
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.445726
#          Iterations: 25
#          Function evaluations: 37
#          Gradient evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.448004
#          Iterations: 25
#          Function evaluations: 37
#          Gradient evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.439829
#          Iterations: 26
#          Function evaluations: 38
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.446001
#          Iterations: 25
#          Function evaluations: 37
#          Gradient evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.446683
#          Iterations: 24
#          Function evaluations: 36
#          Gradient evaluations: 29
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.427700
#          Iterations: 35
#          Function evaluations: 47
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.448159
#          Iterations: 27
#          Function evaluations: 39
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.445895
#          Iterations: 26
#          Function evaluations: 38
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.443756
#          Iterations: 23
#          Function evaluations: 37
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.447796
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.428736
#          Iterations: 26
#          Function evaluations: 38
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.444867
#          Iterations: 24
#          Function evaluations: 38
#          Gradient evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.448293
#          Iterations: 23
#          Function evaluations: 39
#          Gradient evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.445302
#          Iterations: 22
#          Function evaluations: 34
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.447062
#          Iterations: 24
#          Function evaluations: 36
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.441499
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.448290
#          Iterations: 27
#          Function evaluations: 37
#          Gradient evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.448283
#          Iterations: 22
#          Function evaluations: 33
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.448291
#          Iterations: 24
#          Function evaluations: 35
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.447929
#          Iterations: 23
#          Function evaluations: 34
#          Gradient evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.447962
#          Iterations: 22
#          Function evaluations: 33
#          Gradient evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.446198
#          Iterations: 25
#          Function evaluations: 37
#          Gradient evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.447790
#          Iterations: 26
#          Function evaluations: 38
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.443635
#          Iterations: 23
#          Function evaluations: 35
#          Gradient evaluations: 28
# Processed  36 models on 4 predictors in 0.39629387855529785 seconds.
# Optimization terminated successfully.
#          Current function value: 0.444572
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.408023
#          Iterations: 26
#          Function evaluations: 37
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.437626
#          Iterations: 25
#          Function evaluations: 43
#          Gradient evaluations: 32
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.693147
#          Iterations: 0
#          Function evaluations: 15
#          Gradient evaluations: 3
# Optimization terminated successfully.
#          Current function value: 0.444475
#          Iterations: 26
#          Function evaluations: 36
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.435299
#          Iterations: 27
#          Function evaluations: 36
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.404792
#          Iterations: 26
#          Function evaluations: 37
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.444407
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 30
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.429858
#          Iterations: 35
#          Function evaluations: 46
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.435090
#          Iterations: 31
#          Function evaluations: 42
#          Gradient evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.444415
#          Iterations: 28
#          Function evaluations: 39
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.443027
#          Iterations: 28
#          Function evaluations: 39
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.444586
#          Iterations: 28
#          Function evaluations: 39
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.438024
#          Iterations: 28
#          Function evaluations: 39
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.441423
#          Iterations: 28
#          Function evaluations: 39
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.443732
#          Iterations: 28
#          Function evaluations: 39
#          Gradient evaluations: 33
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.430975
#          Iterations: 35
#          Function evaluations: 46
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.443803
#          Iterations: 29
#          Function evaluations: 40
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.443355
#          Iterations: 30
#          Function evaluations: 41
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.439981
#          Iterations: 26
#          Function evaluations: 40
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.444459
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.428157
#          Iterations: 28
#          Function evaluations: 39
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.441779
#          Iterations: 26
#          Function evaluations: 39
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.444643
#          Iterations: 26
#          Function evaluations: 42
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.441425
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.443360
#          Iterations: 27
#          Function evaluations: 38
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.437340
#          Iterations: 27
#          Function evaluations: 38
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.444572
#          Iterations: 27
#          Function evaluations: 37
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.444386
#          Iterations: 26
#          Function evaluations: 38
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.444555
#          Iterations: 26
#          Function evaluations: 37
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.444574
#          Iterations: 27
#          Function evaluations: 37
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.443980
#          Iterations: 26
#          Function evaluations: 37
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.442718
#          Iterations: 27
#          Function evaluations: 38
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.444018
#          Iterations: 29
#          Function evaluations: 40
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.440212
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 30
# Processed  35 models on 5 predictors in 0.4175128936767578 seconds.
# Optimization terminated successfully.
#          Current function value: 0.397467
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 32
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.391675
#          Iterations: 35
#          Function evaluations: 46
#          Gradient evaluations: 40
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.357835
#          Iterations: 29
#          Function evaluations: 71
#          Gradient evaluations: 48
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.693147
#          Iterations: 0
#          Function evaluations: 15
#          Gradient evaluations: 3
# Optimization terminated successfully.
#          Current function value: 0.363208
#          Iterations: 29
#          Function evaluations: 39
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.401613
#          Iterations: 30
#          Function evaluations: 39
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.363644
#          Iterations: 28
#          Function evaluations: 38
#          Gradient evaluations: 32
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.342346
#          Iterations: 35
#          Function evaluations: 46
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.357057
#          Iterations: 33
#          Function evaluations: 44
#          Gradient evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.398908
#          Iterations: 29
#          Function evaluations: 40
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.397432
#          Iterations: 30
#          Function evaluations: 41
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.404268
#          Iterations: 29
#          Function evaluations: 40
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.373360
#          Iterations: 29
#          Function evaluations: 40
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.399566
#          Iterations: 30
#          Function evaluations: 41
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.395336
#          Iterations: 31
#          Function evaluations: 42
#          Gradient evaluations: 36
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.365324
#          Iterations: 35
#          Function evaluations: 46
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.404785
#          Iterations: 31
#          Function evaluations: 42
#          Gradient evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.395542
#          Iterations: 31
#          Function evaluations: 42
#          Gradient evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.403359
#          Iterations: 27
#          Function evaluations: 41
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.404112
#          Iterations: 25
#          Function evaluations: 37
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.340013
#          Iterations: 33
#          Function evaluations: 44
#          Gradient evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.404662
#          Iterations: 28
#          Function evaluations: 41
#          Gradient evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.404740
#          Iterations: 28
#          Function evaluations: 44
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.404472
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.393465
#          Iterations: 29
#          Function evaluations: 40
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.404559
#          Iterations: 27
#          Function evaluations: 38
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.400693
#          Iterations: 30
#          Function evaluations: 40
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.378818
#          Iterations: 30
#          Function evaluations: 42
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.369407
#          Iterations: 28
#          Function evaluations: 39
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.358870
#          Iterations: 28
#          Function evaluations: 37
#          Gradient evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.378078
#          Iterations: 27
#          Function evaluations: 39
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.404516
#          Iterations: 27
#          Function evaluations: 38
#          Gradient evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.398286
#          Iterations: 30
#          Function evaluations: 41
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.404700
#          Iterations: 25
#          Function evaluations: 36
#          Gradient evaluations: 30
# Processed  34 models on 6 predictors in 0.5338129997253418 seconds.
# Optimization terminated successfully.
#          Current function value: 0.357591
#          Iterations: 32
#          Function evaluations: 48
#          Gradient evaluations: 37
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.347337
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.693147
#          Iterations: 0
#          Function evaluations: 15
#          Gradient evaluations: 3
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.351783
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.355549
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Optimization terminated successfully.
#          Current function value: 0.352075
#          Iterations: 31
#          Function evaluations: 46
#          Gradient evaluations: 35
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.349019
#          Iterations: 35
#          Function evaluations: 52
#          Gradient evaluations: 41
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.346704
#          Iterations: 35
#          Function evaluations: 52
#          Gradient evaluations: 41
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.357073
#          Iterations: 35
#          Function evaluations: 52
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.357807
#          Iterations: 32
#          Function evaluations: 49
#          Gradient evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.357203
#          Iterations: 32
#          Function evaluations: 51
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.353112
#          Iterations: 33
#          Function evaluations: 50
#          Gradient evaluations: 39
# Optimization terminated successfully.
#          Current function value: 0.355370
#          Iterations: 34
#          Function evaluations: 51
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.357766
#          Iterations: 34
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.353788
#          Iterations: 35
#          Function evaluations: 52
#          Gradient evaluations: 41
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.357391
#          Iterations: 35
#          Function evaluations: 52
#          Gradient evaluations: 41
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.357583
#          Iterations: 35
#          Function evaluations: 52
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.356598
#          Iterations: 32
#          Function evaluations: 48
#          Gradient evaluations: 37
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.357828
#          Iterations: 29
#          Function evaluations: 46
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.334075
#          Iterations: 34
#          Function evaluations: 50
#          Gradient evaluations: 39
# Optimization terminated successfully.
#          Current function value: 0.356420
#          Iterations: 33
#          Function evaluations: 52
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.357670
#          Iterations: 32
#          Function evaluations: 48
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.357826
#          Iterations: 30
#          Function evaluations: 46
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.353900
#          Iterations: 31
#          Function evaluations: 48
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.357516
#          Iterations: 31
#          Function evaluations: 47
#          Gradient evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.357824
#          Iterations: 33
#          Function evaluations: 48
#          Gradient evaluations: 37
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.343614
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.352129
#          Iterations: 32
#          Function evaluations: 48
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.347844
#          Iterations: 31
#          Function evaluations: 46
#          Gradient evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.353696
#          Iterations: 31
#          Function evaluations: 45
#          Gradient evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.357681
#          Iterations: 34
#          Function evaluations: 51
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.356607
#          Iterations: 34
#          Function evaluations: 51
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.356941
#          Iterations: 31
#          Function evaluations: 48
#          Gradient evaluations: 37
# Processed  33 models on 7 predictors in 0.4982318878173828 seconds.
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.348825
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.693147
#          Iterations: 0
#          Function evaluations: 15
#          Gradient evaluations: 3
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.343907
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.349739
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.343567
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.326456
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.340168
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.351378
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.348397
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.348228
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.343568
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.349393
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.348309
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.338688
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.349952
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.351903
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.348230
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.347954
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
# ...
# Processed  13 models on 27 predictors in 0.42755937576293945 seconds.
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.270496
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.693147
#          Iterations: 0
#          Function evaluations: 15
#          Gradient evaluations: 3
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.272031
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.274513
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.272982
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.274889
#          Iterations: 35
#          Function evaluations: 52
#          Gradient evaluations: 41
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.268228
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.268184
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.261365
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.265460
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.271536
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.274370
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Processed  12 models on 28 predictors in 0.39813876152038574 seconds.
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.267784
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.693147
#          Iterations: 0
#          Function evaluations: 15
#          Gradient evaluations: 3
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.271926
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.270318
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.271572
#          Iterations: 35
#          Function evaluations: 52
#          Gradient evaluations: 41
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.266274
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.265939
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.259021
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.263744
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.269603
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.271999
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Processed  11 models on 29 predictors in 0.3786897659301758 seconds.
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.267019
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.693147
#          Iterations: 0
#          Function evaluations: 15
#          Gradient evaluations: 3
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.270261
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.271274
#          Iterations: 35
#          Function evaluations: 52
#          Gradient evaluations: 41
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.266574
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.265867
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.259282
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.263453
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.269991
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.271885
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 39
# Processed  10 models on 30 predictors in 0.35135412216186523 seconds.
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.267448
#          Iterations: 35
#          Function evaluations: 52
#          Gradient evaluations: 41
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.693147
#          Iterations: 0
#          Function evaluations: 15
#          Gradient evaluations: 3
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.269485
#          Iterations: 35
#          Function evaluations: 52
#          Gradient evaluations: 41
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.266007
#          Iterations: 35
#          Function evaluations: 52
#          Gradient evaluations: 41
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.265859
#          Iterations: 35
#          Function evaluations: 52
#          Gradient evaluations: 41
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.258873
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.262587
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.270724
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.271224
#          Iterations: 35
#          Function evaluations: 52
#          Gradient evaluations: 41
# Processed  9 models on 31 predictors in 0.32689738273620605 seconds.
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.262573
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.693147
#          Iterations: 0
#          Function evaluations: 15
#          Gradient evaluations: 3
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.264625
#          Iterations: 35
#          Function evaluations: 52
#          Gradient evaluations: 41
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.265590
#          Iterations: 35
#          Function evaluations: 52
#          Gradient evaluations: 41
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.254454
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.257419
#          Iterations: 35
#          Function evaluations: 52
#          Gradient evaluations: 41
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.265752
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.263245
#          Iterations: 35
#          Function evaluations: 52
#          Gradient evaluations: 41
# Processed  8 models on 32 predictors in 0.29103994369506836 seconds.
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.693147
#          Iterations: 0
#          Function evaluations: 15
#          Gradient evaluations: 3
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.261552
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.261846
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.249168
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.251653
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.261639
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.261120
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Processed  7 models on 33 predictors in 0.270294189453125 seconds.
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.693147
#          Iterations: 0
#          Function evaluations: 15
#          Gradient evaluations: 3
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.260833
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.248169
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.251449
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.260517
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.259838
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Processed  6 models on 34 predictors in 0.23923587799072266 seconds.
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.693147
#          Iterations: 0
#          Function evaluations: 15
#          Gradient evaluations: 3
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.251483
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.244847
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.220176
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.252319
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Processed  5 models on 35 predictors in 0.23019003868103027 seconds.
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.693147
#          Iterations: 0
#          Function evaluations: 15
#          Gradient evaluations: 3
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.221032
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.221781
#          Iterations: 35
#          Function evaluations: 49
#          Gradient evaluations: 38
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.219704
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 40
# Processed  4 models on 36 predictors in 0.1809537410736084 seconds.
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.693147
#          Iterations: 0
#          Function evaluations: 15
#          Gradient evaluations: 3
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.221764
#          Iterations: 35
#          Function evaluations: 49
#          Gradient evaluations: 38
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.219493
#          Iterations: 35
#          Function evaluations: 49
#          Gradient evaluations: 38
# Processed  3 models on 37 predictors in 0.1356673240661621 seconds.
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.693147
#          Iterations: 0
#          Function evaluations: 15
#          Gradient evaluations: 3
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.219417
#          Iterations: 35
#          Function evaluations: 49
#          Gradient evaluations: 38
# Processed  2 models on 38 predictors in 0.10719680786132812 seconds.
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.693147
#          Iterations: 0
#          Function evaluations: 15
#          Gradient evaluations: 3
# Processed  1 models on 39 predictors in 0.04151415824890137 seconds.
# Total elapsed time: 16.78514003753662 seconds.

# %%
best_sub_plots()

# %%
best_fwd_reg_model = models_best['model'][6]
best_fwd_reg_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              high_risk   No. Observations:                  182
# Model:                          Logit   Df Residuals:                      175
# Method:                           MLE   Df Model:                            6
# Date:                Mon, 13 Mar 2023   Pseudo R-squ.:                  0.4019
# Time:                        16:59:52   Log-Likelihood:                -65.126
# converged:                      False   LL-Null:                       -108.89
# Covariance Type:            nonrobust   LLR p-value:                 9.923e-17
# =================================================================================================================
#                                                     coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# Intercept                                        -8.3975      1.711     -4.907      0.000     -11.752      -5.043
# daly_alc_use_disorders__all_ages_standardized     0.0039      0.001      2.741      0.006       0.001       0.007
# perc_heavy_drinkers_both_sexes                    0.0655      0.026      2.530      0.011       0.015       0.116
# beer_as_share_alcohol_consumption                 0.0209      0.012      1.684      0.092      -0.003       0.045
# spirits_as_share_alcohol_consumption              0.0257      0.011      2.278      0.023       0.004       0.048
# total_alcohol_consumption_per_capita_liters       0.4220      0.093      4.552      0.000       0.240       0.604
# gdp_per_capita                                -6.527e-05   1.94e-05     -3.359      0.001      -0.000   -2.72e-05
# =================================================================================================================
# """

# %%
def forward_k_fold_results():
    total_accuracy=0
    total_fnr=0
    for i in range(len(trains)):
        test = trains[i]
        df = pd.DataFrame()
        for j in range(len(trains)):
            if j != i:
                df = df.append(trains[i])
        forward_model = sm.logit(formula='high_risk~daly_alc_use_disorders__all_ages_standardized+perc_heavy_drinkers_both_sexes+beer_as_share_alcohol_consumption+spirits_as_share_alcohol_consumption+total_alcohol_consumption_per_capita_liters+gdp_per_capita',data= df).fit(method='bfgs')
        result = model_results(test,test.high_risk,model)
        total_accuracy += result[1]
        total_fnr += result[0]
    print("Average Classification Accuracy: {:.1%}".format(total_accuracy/len(trains)))
    print("Average FNR: {:.1%}".format(total_fnr/len(trains)))
forward_k_fold_results()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.255083
#          Iterations: 35
#          Function evaluations: 49
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000002
#          Iterations: 35
#          Function evaluations: 51
#          Gradient evaluations: 41
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 35
#          Function evaluations: 48
#          Gradient evaluations: 38
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.349472
#          Iterations: 35
#          Function evaluations: 49
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000220
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.002471
#          Iterations: 35
#          Function evaluations: 49
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 35
#          Function evaluations: 50
#          Gradient evaluations: 40
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000004
#          Iterations: 35
#          Function evaluations: 48
#          Gradient evaluations: 39
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000004
#          Iterations: 35
#          Function evaluations: 49
#          Gradient evaluations: 39
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.693147
#          Iterations: 0
#          Function evaluations: 15
#          Gradient evaluations: 3
# Average Classification Accuracy: 95.1%
# Average FNR: 12.6%

# %% [markdown]
# ### Code fitting the final model

# %% [markdown]
# Put the code(s) that fit the final model(s) in separate cell(s), i.e., the code with the `.ols()` or `.logit()` functions.

# %% [markdown]
# ## Conclusions and Recommendations to stakeholder(s)
#
# You may or may not have code to put in this section. Delete this section if it is irrelevant.
